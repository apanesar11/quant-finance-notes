# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Sampling

# %%
X = np.random.normal(0, 1, 10000)

# %%
plt.hist(X);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97f65567ecc3> in <module>()
# ----> 1 plt.hist(X);
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Basic graph

# %%
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.plot(X)
plt.plot(Y)
plt.xlabel('Time')
plt.ylabel('Returns')
plt.legend(['X', 'Y'])

# %% [markdown]
# ## Statistics

# %%
np.mean(X)
# Out:
# 0.049107390063610777

# %% [markdown]
# ## Real Pricing Data

# %%
data = get_pricing('AAPL', start_date='2020-01-01', end_date='2020-10-13')
prices = data['price']
highs = data['high']
lows = data['low']

plt.plot(prices)
plt.plot(highs)
plt.plot(lows)

# plt.plot(prices.index, prices.values)

# %%
pct_change = prices.pct_change()[1:]
plt.hist(pct_change);
plt.xlabel('Returns');
plt.ylabel('Count');
plt.legend(['AAPL Returns'])

# %%
# is the graph above normal? let's test this
data = np.random.normal(np.mean(prices), np.std(prices), 100)
plt.hist(data);
# nope, definitely not normal

# %%
MAVG = pd.rolling_mean(prices, window=50)
plt.plot(MAVG);
plt.plot(prices);
# Out:
# /venvs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=50).mean()
#   """Entry point for launching an IPython kernel.
